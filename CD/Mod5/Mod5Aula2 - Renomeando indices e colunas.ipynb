# %% [markdown]
# # Índice <a name="Contents"></a>
# 1. [Importando bibliotecas](#import)
# 2. [Construindo um dataframe](#read)
# 3. [Renomeando colunas](#colunas)
# 4. [Renomeando índices](#indices)

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# # 2. Construindo um dataframe <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df = pd.DataFrame(
    np.random.randn(9, 4)*100,
    index=["A", "B", "C", "D", "E", "F", "G", "H", "I"],
    columns=["coluna1", "coluna2", "coluna3","coluna4"],
)
df
# Out:
#       coluna1     coluna2     coluna3     coluna4
# A  -30.644203   41.203134   33.322327 -132.807090
# B  146.434345   90.395972  -26.554196  -57.473422
# C  -30.605205   -8.840280 -122.400550  -13.989806
# D   29.262331   21.423099   59.137421   49.710905
# E  -78.791742    2.358687 -126.906484   61.715297
# F -104.126081  -58.070948  -46.377619  -27.289869
# G -141.546108  -30.652197  -37.661391  -43.609308
# H   64.058216   38.518622   75.555030  -52.630916
# I   28.061703 -112.492156  -46.273001   36.130433

# %% [markdown]
# # 3. Renomeando colunas <a name="colunas"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df.columns
# Out:
# Index(['coluna1', 'coluna2', 'coluna3', 'coluna4'], dtype='object')

# %%
df.columns = ['segunda', 'terça', 'quarta', 'quinta']

# %%
df.columns
# Out:
# Index(['segunda', 'terça', 'quarta', 'quinta'], dtype='object')

# %%
df
# Out:
#       segunda       terça      quarta      quinta
# A  -30.644203   41.203134   33.322327 -132.807090
# B  146.434345   90.395972  -26.554196  -57.473422
# C  -30.605205   -8.840280 -122.400550  -13.989806
# D   29.262331   21.423099   59.137421   49.710905
# E  -78.791742    2.358687 -126.906484   61.715297
# F -104.126081  -58.070948  -46.377619  -27.289869
# G -141.546108  -30.652197  -37.661391  -43.609308
# H   64.058216   38.518622   75.555030  -52.630916
# I   28.061703 -112.492156  -46.273001   36.130433

# %% [markdown]
# # 4. Renomeando índices <a name="indices"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df['coluna5'] = ['letraA','letraB','letraC','letraD','letraE','letraF','letraG','letraH','letraI']

# %%
df
# Out:
#       segunda       terça      quarta      quinta coluna5
# A  -30.644203   41.203134   33.322327 -132.807090  letraA
# B  146.434345   90.395972  -26.554196  -57.473422  letraB
# C  -30.605205   -8.840280 -122.400550  -13.989806  letraC
# D   29.262331   21.423099   59.137421   49.710905  letraD
# E  -78.791742    2.358687 -126.906484   61.715297  letraE
# F -104.126081  -58.070948  -46.377619  -27.289869  letraF
# G -141.546108  -30.652197  -37.661391  -43.609308  letraG
# H   64.058216   38.518622   75.555030  -52.630916  letraH
# I   28.061703 -112.492156  -46.273001   36.130433  letraI

# %%
df.set_index('coluna5')
